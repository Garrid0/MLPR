# %% [markdown]
# # Imports

# %%
# NOT ALLOWED THESE LIBRARIES
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
amp_data = np.load('amp_data.npz')['amp_data']

# %% [markdown]
# # 1 A

# %%
plt.plot(range(len(amp_data)),amp_data)
plt.xlabel("Data Point (proportional to time)")
plt.ylabel("Amplitude")
plt.show()

# %%
plt.hist(amp_data, bins=1000)
plt.title("Histogram of amplitudes.")
plt.xlabel("Amplitude")
plt.ylabel("Frequency of ocurrence")
plt.show()

# %% [markdown]
# # 1 B

# %%
amp_data_cut = amp_data[:-6]    # Remove remainder iff div into sets of 21
amp_data_matrix = amp_data_cut.reshape((1605394, 21))   # reshape as Nx21 matrix.

def train_val_test_split(matrix, train_prop = 0.7, val_prop = 0.15, seed=0):
    np.random.seed(seed)
    matrix_shuf = np.random.permutation(matrix)  # shuffle on 1st axis (rows)

    n_rows = matrix_shuf.shape[0]
    #floor non-integer proportions (without math module)
    rows_train = int(n_rows*train_prop)
    rows_val = int(n_rows*val_prop)

    data_train = matrix_shuf[:rows_train,:]
    # Need cumulative partition start and stop.
    start_val, stop_val = rows_train, rows_train + rows_val
    data_val = matrix_shuf[start_val:stop_val,:]
    data_test = matrix_shuf[stop_val:,:]  # rest is test (doesn´t miss dps)

    return data_train, data_val, data_test

amp_data_train, amp_data_val, amp_data_test = train_val_test_split(amp_data_matrix)

# First 20 cols training and 21st col (last) are labels.
X_shuf_train, y_shuf_train = amp_data_train[:,:20], amp_data_train[:,-1:]
X_shuf_val, y_shuf_val = amp_data_val[:,:20], amp_data_val[:,-1:]
X_shuf_test, y_shuf_test = amp_data_test[:,:20], amp_data_test[:,-1:]

# %%
amp_data_cut = amp_data[:-6]
plt.plot(amp_data_cut)

# %%
amp_data_matrix = amp_data_cut.reshape((1605394, 21))
amp_data_matrix.shape
print(amp_data_matrix)
# Out:
# [[ 0.00000000e+00 -3.05175781e-05  6.10351562e-05 ...  6.10351562e-05
#   -6.10351562e-05  6.10351562e-05]
#  [-6.10351562e-05  6.10351562e-05 -6.10351562e-05 ... -6.10351562e-05
#    6.10351562e-05 -3.05175781e-05]
#  [ 0.00000000e+00  0.00000000e+00 -3.05175781e-05 ... -6.10351562e-05
#    1.22070312e-04 -1.52587891e-04]
#  ...
#  [ 6.10351562e-05 -6.10351562e-05  6.10351562e-05 ...  3.05175781e-05
#   -6.10351562e-05  6.10351562e-05]
#  [-6.10351562e-05  6.10351562e-05 -6.10351562e-05 ...  9.15527344e-05
#   -9.15527344e-05  6.10351562e-05]
#  [-3.05175781e-05  0.00000000e+00  6.10351562e-05 ... -6.10351562e-05
#    6.10351562e-05 -3.05175781e-05]]

# %%
amp_data_shuf = np.random.permutation(amp_data_matrix)
prop_train = 0.7
prop_val = 0.15
n_rows = amp_data_shuf.shape[0]
#floor non-integer proportions (without math module)
rows_train = int(n_rows*prop_train)
rows_val = int(n_rows*prop_val)
rows_test = n_rows - rows_train - rows_val  #ensure not missing datapoints

# %%
amp_data_train = amp_data_shuf[:rows_train,:]
# Need cumulative partition start and stop.
start_val, stop_val = rows_train, rows_train + rows_val
amp_data_val = amp_data_shuf[start_val:stop_val,:]
amp_data_test = amp_data_shuf[stop_val:,:]

# %%
print(amp_data_train.shape, amp_data_val.shape, amp_data_test.shape)
# Out:
# (1123775, 21) (240809, 21) (240810, 21)

# %%
# First 20 cols training and 21st col (last) are labels.
X_shuf_train, y_shuf_train = amp_data_train[:,:20], amp_data_train[:,-1:]
X_shuf_val, y_shuf_val = amp_data_val[:,:20], amp_data_val[:,-1:]
X_shuf_test, y_shuf_test = amp_data_test[:,:20], amp_data_test[:,-1:]

# %%
# Out:
# 23 45 50
# 23 45 50
